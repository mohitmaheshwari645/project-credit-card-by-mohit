# %% [markdown]
# # Importing Liberaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## import DataSet

# %%
df=pd.read_csv("dataset.csv")
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df["LUNG_CANCER"].value_counts()
# Out:
# LUNG_CANCER
# YES    1518
# NO     1482
# Name: count, dtype: int64

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
# ...

# %% [markdown]
# This Dataset conatains values in form 1 and 2,
# - 1=Yes and 2=No.

# %% [markdown]
# Check for null values:

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
df_cat=df.select_dtypes(include="object")
df_cat.head()
# Out:
#   GENDER LUNG_CANCER
# 0      M          NO
# 1      F          NO
# 2      F         YES
# 3      M         YES
# 4      F          NO

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df.shape
# Out:
# (3000, 16)

# %%
#Checking for Duplicates
df.duplicated().sum()
# Out:
# 2

# %%
#Removing Duplicates
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 2998 non-null   object
#  1   AGE                    2998 non-null   int64
#  2   SMOKING                2998 non-null   int64
#  3   YELLOW_FINGERS         2998 non-null   int64
#  4   ANXIETY                2998 non-null   int64
#  5   PEER_PRESSURE          2998 non-null   int64
#  6   CHRONIC_DISEASE        2998 non-null   int64
#  7   FATIGUE                2998 non-null   int64
#  8   ALLERGY                2998 non-null   int64
#  9   WHEEZING               2998 non-null   int64
#  10  ALCOHOL_CONSUMING      2998 non-null   int64
#  11  COUGHING               2998 non-null   int64
#  12  SHORTNESS_OF_BREATH    2998 non-null   int64
#  13  SWALLOWING_DIFFICULTY  2998 non-null   int64
#  14  CHEST_PAIN             2998 non-null   int64
# ...

# %%
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  2998.000000  2998.000000     2998.000000  2998.000000    2998.000000
# mean     55.171448     1.491328        1.514009     1.493996       1.498666
# std      14.728302     0.500008        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      2998.000000  2998.000000  2998.000000  2998.000000
# mean          1.509673     1.489660     1.507005     1.497332
# std           0.499990     0.499976     0.500034     0.500076
# ...

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df["AGE"].mean()
# Out:
# 55.1714476317545

# %%
df_gender=df[["GENDER","LUNG_CANCER"]]
plt.figure(figsize=(6,3))
sns.countplot(x="GENDER",hue="LUNG_CANCER",data=df_gender)
# Out:
# <Axes: xlabel='GENDER', ylabel='count'>

# %% [markdown]
# - Both Male and Female are Equally affected by Lung Cancer.

# %%
#Correlation Between
corr=df.corr(numeric_only=True).round(2)
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# - Having seen the heatmap, Not much correlation between different features but we can figure out something like:
#  - Smoking leads to chronic desease
#  - Alcohol consumption may lead to yellowish Fingers.
#  - Alcohol may lead to Swallowing Difficulties
#  - Fatigue and Anxiety may lead to Shortness of breath.

# %% [markdown]
# ### Smoker and Non-Smoker

# %%
sns.countplot(x="SMOKING",data=df,hue="SMOKING")
# Out:
# <Axes: xlabel='SMOKING', ylabel='count'>

# %% [markdown]
# - Smokers are slightly more in the Dataset.

# %% [markdown]
# ### % of people with lung cancer in the Dataset

# %%
pie_df=df["LUNG_CANCER"].value_counts()
pie_df.plot(kind="pie",figsize=(8,8),autopct="%1.1f%%")
plt.show()

# %%
df["LUNG_CANCER"].value_counts(normalize=True)*100
# Out:
# LUNG_CANCER
# YES    50.6004
# NO     49.3996
# Name: proportion, dtype: float64

# %% [markdown]
# - 50% of all the surveyors wer diagnosed with lung cancer.

# %%
plt.figure(figsize=(12,8))
sns.histplot(df["AGE"])
# Out:
# <Axes: xlabel='AGE', ylabel='Count'>

# %% [markdown]
# - Surveyors are from age 30 to 80 usually.

# %%
df.GENDER.value_counts()
# Out:
# GENDER
# M    1512
# F    1486
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(x="GENDER",data=df, hue="GENDER")
# Out:
# <Axes: xlabel='GENDER', ylabel='count'>

# %% [markdown]
# - Surveyors are males and female both, but males are slightly more.

# %%
# Lung Cancer across Genders
plt.figure(figsize=(10,10))
sns.countplot(data=df,x='GENDER',hue='LUNG_CANCER')
plt.legend(["Has cancer", 'Does not have cancer'])

# %% [markdown]
# Both Male-Surveyors have cancer, and not have are almost same and similar for Female surveyors.

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
X = ['YELLOW_FINGERS', 'ANXIETY','PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING','ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',  'SWALLOWING_DIFFICULTY', 'CHEST_PAIN']
fig, ax = plt.subplots(nrows = 4, ncols = 3) #16 subplots
fig.set_size_inches(16,24) #set figure size

for i in range(4):
    for j in range(3):
        sns.countplot(x =df[X[3 * i + j]] , hue=df['LUNG_CANCER'], ax = ax[i][j]) # count plot

# %% [markdown]
# - After plotting multiple countplots for the different features, we can see that most surveyors said yes to having symptoms such as yellow fingers, coughing, fatigue, shortness of breath and chest pain meaning these are the primary/more crucial symptoms that people should look out for as they may be at risk of having cancer.

# %% [markdown]
# Let's analyze the likeness of having the symptoms a little more.

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=df,x='COUGHING',hue='LUNG_CANCER')
plt.legend(["Has cancer", 'Does not have cancer'])

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=df,x='YELLOW_FINGERS',hue='LUNG_CANCER')
plt.legend(["Has cancer", 'Does not have cancer'])

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=df,x='SHORTNESS_OF_BREATH',hue='LUNG_CANCER')
plt.legend(["Has cancer", 'Does not have cancer'])

# %% [markdown]
# - Interestingly, in all three of the plots we can see that it doesn't really matter if the symptoms are showing or not as some people may have cancer yet not show any symptoms. So, regular checkups would be wiser than waiting for symptoms to show up as that may lead it to deteriorate conditions.

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df,x='ANXIETY',hue='SHORTNESS_OF_BREATH')
plt.legend(["Difficulty Breathing", 'No Difficulty Breathing'])

# %% [markdown]
# - Earlier, I inferred that more anxiety may lead to more difficulty in breathing but we can see from this visualization that it does not really matter if someone has anxiety or not, most surveyors have difficulty breathing and this may be directly correlated to having cancer.

# %% [markdown]
# # Conclusion:
# - Based on the data, we've made inferences such as relationships between symptoms and the likeliness of having lung cancer and relationships with gender, age, etc.
#
# - Training a machine learning model with this dataset could help us predict whether or not someone will be diagnosed with lung cancer or not.
